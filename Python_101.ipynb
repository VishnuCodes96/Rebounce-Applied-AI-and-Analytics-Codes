# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuCodes96/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 Starting")
# Out:
# MP1 Starting

# %%
name = "Vishnu Kiran"
city = "Hyderabad"
year_of_birth = 1996
age = 2026 - year_of_birth
print("Hi, I'm",name,"from",city,".","This year I turn",age,"years old.") # Printing values stored in variables using concatenation
# Out:
# Hi, I'm Vishnu Kiran from Hyderabad . This year I turn 30 years old.

# %%
inr_holding = 75000
jap_yen = 1.75 * inr_holding
jap_yen_str = format(jap_yen,'.2f') # Formatting a string using format function
print('Rs.',inr_holding,"converts to Yen",jap_yen_str)
# Out:
# Rs. 75000 converts to Yen 131250.00

# %%
bread = 40
milk = 65.50
eggs = 120
total = bread + milk + eggs
formatted_total = format(total,'.2f')
avg = round(total / 3,2)
print("Total: Rs",formatted_total)
print("Average per item: Rs",avg)
# Out:
# Total: Rs 225.50
# Average per item: Rs 75.17

# %%
number = input("enter a number to check if it is even or odd: ")
number_int = int(number)
print("Is",number_int,"even?",number_int%2==0)
# Out:
# enter a number to check if it is even or odd: 37
# Is 37 even? False

# %%
password = input("password containing atleast 8 characters and containing '@': ")
print('Password: ',password)
print('Length OK (>=8):',len(password)>=8)
print('Contains @ :', '@' in password)
print('Strong:', len(password)>=8 and '@' in password)
# Out:
# password containing atleast 8 characters and containing '@': strong@123
# Password:  strong@123
# Length OK (>=8): True
# Contains @ : True
# Strong: True

# %%
list_of_attendees = ['Arjit','Vishnu','Priya','Rohan','Pratheek','Sachin','Dhoni','Yuvaraj']
print('Total Attendees:',len(list_of_attendees))
print('First Attendee:',list_of_attendees[0])
print('Last two attendees:',list_of_attendees[-2:])
print('Firt three alphabetically:',sorted(list_of_attendees)[0:3])
# Out:
# Total Attendees: 8
# First Attendee: Arjit
# Last two attendees: ['Dhoni', 'Yuvaraj']
# Firt three alphabetically: ['Arjit', 'Dhoni', 'Pratheek']

# %%
contact_book ={
    'Vishnu': 1234567890,
    'Kiran' : 2345678901,
    'Sachin' : 3456789012,
    'Dhoni' : 4567890123,
    'Yuvaraj' : 5678901234,
}
print(f"Sachin's number: {contact_book['Sachin']}")
contact_book['Amit'] = 7890123456 # Adding an entry into the already existing dictionary
print(f'After adding Amit: {len(contact_book)} contacts')
# Out:
# Sachin's number: 3456789012
# After adding Amit: 6 contacts

# %%
even_num_sq_list = [num**2 for num in range(1,21) if num % 2 == 0]
print(even_num_sq_list)
# Out:
# [4, 16, 36, 64, 100, 144, 196, 256, 324, 400]

# %%
products = [
    ("Notebook", 250),
    ("Pen", 20),
    ("Backpack", 1800),
    ("Eraser", 15),
    ("Water Bottle", 350),
]
# Each tuple has two values, index 1 is product price
# key --> is a function that tells Python what value to compare when sorting
sorted_products = sorted(products, key=lambda product: product[1])

print(sorted_products)
# Out:
# [('Eraser', 15), ('Pen', 20), ('Notebook', 250), ('Water Bottle', 350), ('Backpack', 1800)]
